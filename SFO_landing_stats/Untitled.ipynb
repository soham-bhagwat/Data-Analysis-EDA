# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata('data.sfgov.org',
                 '0r5XNOm1weRyhpaOSPLTJ7TWN',
                  username='sohambhagwat2@gmail.com',
                  password="SoData007#")

results = client.get("fpux-q53t", limit=200000)

# %%
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#       activity_period activity_period_start_date  \
# 0              199907    1999-07-01T00:00:00.000
# 1              199907    1999-07-01T00:00:00.000
# 2              199907    1999-07-01T00:00:00.000
# 3              199907    1999-07-01T00:00:00.000
# 4              199907    1999-07-01T00:00:00.000
# ...               ...                        ...
# 41876          202404    2024-04-01T00:00:00.000
# 41877          202404    2024-04-01T00:00:00.000
# 41878          202404    2024-04-01T00:00:00.000
# 41879          202404    2024-04-01T00:00:00.000
# 41880          202404    2024-04-01T00:00:00.000
#
#                              operating_airline operating_airline_iata_code  \
# 0                                 ATA Airlines                          TZ
# 1                                 ATA Airlines                          TZ
# 2                                 ATA Airlines                          TZ
# ...

# %%
results_df.dtypes
# Out:
# activity_period                object
# activity_period_start_date     object
# operating_airline              object
# operating_airline_iata_code    object
# published_airline              object
# published_airline_iata_code    object
# geo_summary                    object
# geo_region                     object
# landing_aircraft_type          object
# aircraft_body_type             object
# aircraft_manufacturer          object
# aircraft_model                 object
# aircraft_version               object
# landing_count                  object
# total_landed_weight            object
# data_as_of                     object
# data_loaded_at                 object
# dtype: object
