# %% [markdown]
# <a href="https://colab.research.google.com/github/the-soham/Data-Analysis/blob/main/S4E7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
df = pd.read_csv('/content/train.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1           35                   0
# 1   1    Male   43                1           28                   0
# 2   2  Female   25                1           14                   1
# 3   3  Female   35                1            1                   0
# 4   4  Female   36                1           15                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes           65101                   124      187
# 1   > 2 Years            Yes           58911                    26      288
# 2    < 1 Year             No           38043                   152      254
# 3    1-2 Year            Yes            2630                   156       76
# 4    1-2 Year             No           31951                   152      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1048575 non-null  int64
#  1   Gender                1048575 non-null  object
#  2   Age                   1048575 non-null  int64
#  3   Driving_License       1048575 non-null  int64
#  4   Region_Code           1048575 non-null  int64
#  5   Previously_Insured    1048575 non-null  int64
#  6   Vehicle_Age           1048575 non-null  object
#  7   Vehicle_Damage        1048575 non-null  object
#  8   Annual_Premium        1048575 non-null  int64
#  9   Policy_Sales_Channel  1048575 non-null  int64
#  10  Vintage               1048575 non-null  int64
#  11  Response              1048575 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 96.0+ MB

# %%
df.describe()
# Out:
#                  id           Age  Driving_License   Region_Code  \
# count  1.048575e+06  1.048575e+06     1.048575e+06  1.048575e+06
# mean   5.242870e+05  3.840099e+01     9.980335e-01  2.643371e+01
# std    3.026977e+05  1.500983e+01     4.430139e-02  1.298846e+01
# min    0.000000e+00  2.000000e+01     0.000000e+00  0.000000e+00
# 25%    2.621435e+05  2.400000e+01     1.000000e+00  1.500000e+01
# 50%    5.242870e+05  3.600000e+01     1.000000e+00  2.800000e+01
# 75%    7.864305e+05  4.900000e+01     1.000000e+00  3.500000e+01
# max    1.048574e+06  8.500000e+01     1.000000e+00  5.200000e+01
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel       Vintage  \
# count        1.048575e+06    1.048575e+06          1.048575e+06  1.048575e+06
# mean         4.622483e-01    3.044954e+04          1.123353e+02  1.639608e+02
# std          4.985730e-01    1.643956e+04          5.408467e+01  7.993389e+01
# min          0.000000e+00    2.630000e+03          1.000000e+00  1.000000e+01
# 25%          0.000000e+00    2.526500e+04          2.900000e+01  9.900000e+01
# 50%          0.000000e+00    3.181700e+04          1.500000e+02  1.660000e+02
# 75%          1.000000e+00    3.946000e+04          1.520000e+02  2.320000e+02
# max          1.000000e+00    5.401650e+05          1.630000e+02  2.990000e+02
#
#            Response
# count  1.048575e+06
# mean   1.227037e-01
# std    3.280969e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
#eda
plt.figure(figsize=(7, 4))
sns.boxplot(x=df['Annual_Premium'])
plt.title('Distribution of Annual_Premium')
plt.xlabel('Annual_Premium')
plt.ylabel('Frequency')
plt.show()

# %%
#eda
plt.figure(figsize=(7, 4))
sns.countplot(x=df['Gender'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x=df['Driving_License'])
plt.title('Distribution of Driving_License')
plt.xlabel('Driving_License')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x=df['Vehicle_Damage'])
plt.title('Distribution of Vehicle_Damage')
plt.xlabel('Vehicle_Damage')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'])
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Region_Code'], kde=False, bins=12)
plt.title('Distribution of Region_Code')
plt.xlabel('Region_Code')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x=df['Vehicle_Age'])
plt.title('Distribution of Vehicle_Age')
plt.xlabel('Vehicle_Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x=df['Response'], hue = df['Response'])
plt.title('Distribution of Response')
plt.xlabel('Response')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(x=df['Policy_Sales_Channel'])
plt.title('Distribution of Policy_Sales_Channel')
plt.xlabel('Policy_Sales_Channel')
plt.ylabel('Frequency')
plt.show()

# %%
##handling categorical vars
gender_map = {
    "Male" : 0,
    "Female" : 1
}

# %%
df.Gender = df.Gender.map(gender_map)

# %%
vehicle_damage_map = {
    "Yes": 1,
    "No": 0
}

# %%
df.Vehicle_Damage = df.Vehicle_Damage.map(vehicle_damage_map)

# %%
age_map = {
    "< 1 Year" : 0,
    "1-2 Year" : 1,
    "> 2 Years" : 2
}

# %%
df.Vehicle_Age = df.Vehicle_Age.map(age_map)

# %%
df.Vehicle_Age.value_counts()
# Out:
# Vehicle_Age
# 1    546019
# 0    459248
# 2     43308
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# id                      int64
# Gender                  int64
# Age                     int64
# Driving_License         int64
# Region_Code             int64
# Previously_Insured      int64
# Vehicle_Age             int64
# Vehicle_Damage          int64
# Annual_Premium          int64
# Policy_Sales_Channel    int64
# Vintage                 int64
# Response                int64
# dtype: object

# %%
#modelling
df = df.drop('id', axis=1)
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   21                1           35                   0            1
# 1       0   43                1           28                   0            2
# 2       1   25                1           14                   1            0
# 3       1   35                1            1                   0            1
# 4       1   36                1           15                   1            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1           65101                   124      187         0
# 1               1           58911                    26      288         1
# 2               0           38043                   152      254         0
# 3               1            2630                   156       76         0
# 4               0           31951                   152      294         0
